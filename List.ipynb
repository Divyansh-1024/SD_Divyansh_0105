# %%
l=[1,25,"college",True,5+7j,345.456]

# %%
l[4].real
# Out:
# 5.0

# %%
l[: : 2]
# Out:
# [1, 'college', (5+7j)]

# %%
l[: : -1]
# Out:
# [345.456, (5+7j), True, 'college', 25, 1]

# %%
l[-1:-5:-2]
# Out:
# [345.456, True]

# %%
l[1:6:-2]
# Out:
# []

# %%
l[-1:-7:-5]
# Out:
# [345.456, 1]

# %%
l.append(5)

# %%
l
# Out:
# [1, 25, 'college', True, (5+7j), 345.456, 5, 5, 5, 5, 5]

# %%
l
# Out:
# [1, 25, 'college', True, (5+7j), 345.456, 5, 5, 5, 5, 5, 5]

# %%
s="today is my first day"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1520/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
l[s]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1520/1147026784.py in <cell line: 0>()
# ----> 1 l[s]
#
# TypeError: list indices must be integers or slices, not str

# %%
list(s)+l
# Out:
# ['t',
#  'o',
#  'd',
#  'a',
#  'y',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'm',
#  'y',
#  ' ',
#  'f',
#  'i',
#  'r',
#  's',
#  't',
#  ' ',
#  'd',
#  'a',
#  'y',
#  1,
#  25,
#  'college',
#  True,
#  (5+7j),
#  345.456,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5]

# %%
l[2][0:2:]
# Out:
# 'co'

# %%
str(l[3])[0:2]
# Out:
# 'Tr'

# %%
l.insert(5,34)

# %%
l
# Out:
# [1, 25, 'college', True, (5+7j), 34, 34, 345.456, 5, 5, 5, 5, 5, 5, 5]

# %%
name =input("Enter your Name:")
# Out:
# Enter your Name:divyansh

# %%
print(name)
# Out:
# divyansh

# %%
x="10"
y=int(x)
print(y)
# Out:
# 10

# %%
x="3.14"
y=float(x)
print(y)
# Out:
# 3.14

# %%
x=24
y=str(x)
print(y)
# Out:
# 24

# %%
x=[1,2,3]
y=tuple(x)
print(y)
# Out:
# (1, 2, 3)

# %%
l1=[42,60,"college",True,42.56]

# %%
l1.append(5)

# %%
l1
# Out:
# [42, 60, 'college', True, 42.56, 5, 5]

# %%
l1.pop()
l1
# Out:
# [42, 60, 'college']

# %%
l1.append(42.56)

# %%
l1
# Out:
# [42, 60, 'college', 42.56, 42.56]

# %%
l1.pop()
# Out:
# 42.56

# %%
l1
# Out:
# [42, 60, 'college']

# %%
l
