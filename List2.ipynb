# %%
l=[1,345,45,"clg",True,4+5j,45.26]

# %%
l[5].real
# Out:
# 4.0

# %%
l[0:5:4]
# Out:
# [1, True]

# %%
l[-1:-5:-2]
# Out:
# [45.26, True]

# %%
s="maritimeexpertise"

# %%
list(s)+l
# Out:
# ['m',
#  'a',
#  'r',
#  'i',
#  't',
#  'i',
#  'm',
#  'e',
#  'e',
#  'x',
#  'p',
#  'e',
#  'r',
#  't',
#  'i',
#  's',
#  'e',
#  1,
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26]

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'cl'

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l1=[3,4,5]

# %%
l+l1
# Out:
# [1, 345, 45, 'clg', True, (4+5j), 45.26, 3, 4, 5]

# %%
l1*3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l.append(8)

# %%
l
# Out:
# [1, 345, 45, 'clg', True, (4+5j), 45.26, 8, 8]

# %%
l.append(s)

# %%
s
# Out:
# 'maritimeexpertise'

# %%
l.append(l1)

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26,
#  8,
#  8,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 5],
#  [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l.extend("clg")

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26,
#  8,
#  8,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 5],
#  [3, 4, 5],
#  'c',
#  'l',
#  'g',
#  'c',
#  'l',
#  'g']

# %%
l.extend([1,3,5])

# %%
l
# Out:
# [1,
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26,
#  8,
#  8,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 5],
#  [3, 4, 5],
#  'c',
#  'l',
#  'g',
#  'c',
#  'l',
#  'g',
#  1,
#  3,
#  5,
#  1,
#  3,
#  5]

# %%
l.insert(1,"and")

# %%
l
# Out:
# [1,
#  'and',
#  'and',
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26,
#  8,
#  8,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3, 4, 5],
#  [3, 4, 5],
#  'c',
#  'l',
#  'g',
#  'c',
#  'l',
#  'g',
#  1,
#  3,
#  5,
#  1,
#  3,
#  5]

# %%
l1.pop(2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1726/2644557776.py in <cell line: 0>()
# ----> 1 l1.pop(2)
#
# IndexError: pop index out of range

# %%
l1
# Out:
# [3, 4]

# %%
l1.remove(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1726/4259717016.py in <cell line: 0>()
# ----> 1 l1.remove(4)
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# [3]

# %%
l.reverse()

# %%
l
# Out:
# [1,
#  'and',
#  'and',
#  345,
#  45,
#  'clg',
#  True,
#  (4+5j),
#  45.26,
#  8,
#  8,
#  'maritimeexpertise',
#  'maritimeexpertise',
#  'maritimeexpertise',
#  [3],
#  [3],
#  'c',
#  'l',
#  'g',
#  'c',
#  'l',
#  'g',
#  1,
#  3,
#  5,
#  1,
#  3,
#  5]

# %%
l2=[1,3,5,7,9,11,13,67]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 3, 5, 7, 9, 11, 13, 67]

# %%
l2.reverse()

# %%
l2
# Out:
# [67, 13, 11, 9, 7, 5, 3, 1]

# %%
l2.index(11)
# Out:
# 2

# %%
l2.count(7)
# Out:
# 1

# %%
s.replace('m','n')
# Out:
# 'naritineexpertise'

# %%
t=(1,3,5,'Clg',25.25,True,45+45j,[3,5,7])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 8

# %%
t[-1]
# Out:
# [3, 5, 7]

# %%
t.append(45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1726/782907367.py in <cell line: 0>()
# ----> 1 t.append(45)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t.remove(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1726/3049272562.py in <cell line: 0>()
# ----> 1 t.remove(3)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %%
t.pop(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1726/2035704701.py in <cell line: 0>()
# ----> 1 t.pop(4)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t*3
# Out:
# (1,
#  3,
#  5,
#  'Clg',
#  25.25,
#  True,
#  (45+45j),
#  [3, 5, 7],
#  1,
#  3,
#  5,
#  'Clg',
#  25.25,
#  True,
#  (45+45j),
#  [3, 5, 7],
#  1,
#  3,
#  5,
#  'Clg',
#  25.25,
#  True,
#  (45+45j),
#  [3, 5, 7])

# %%
d1={}

# %%
type(d1)
# Out:
# dict

# %%
s2={32,42,"clg",45+45j,25.25,(3,4,5)}

# %%
s2
# Out:
# {(3, 4, 5), (45+45j), 25.25, 32, 42, 'clg'}

# %%
s3={1,1,1,1,1,4,4,4,3,3,3}

# %%
s3
# Out:
# {1, 3, 4}

# %%
l5=[2,4,7,3,2,5,7,9,"Clg","clg"]

# %%
s3.add(6)

# %%
s3
# Out:
# {1, 3, 4, 6}

# %%
d={}

# %%
type(d )
# Out:
# dict

# %%
d1={'key' :"clg"}

# %%
d1
# Out:
# {'key': 'clg'}

# %%
d2={'name':"Divyansh","E mail":"dd@gmail.com","number": 324526}

# %%
d3={234:'clg','_wer':'Kumar',True:2345}

# %%
d3[234]
# Out:
# 'clg'

# %%
d3[1]
# Out:
# 2345

# %%
d3[True]
# Out:
# 2345
