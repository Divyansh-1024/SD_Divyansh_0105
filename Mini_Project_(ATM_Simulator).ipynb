# %%
customer={"Card number": 10052430 , "pin" : 3007 , "Amount" : 1000}
def Withdrwal():
  pin=int(input("Enter your pin"))
  if pin==customer["pin"]:
    print("Enter the amount")
    Withdrawl_Amount=int(input())
    if Withdrawl_Amount>customer["Amount"]:
      print("Insufficient Balance")
    else :
      customer["Amount"]=customer["Amount"]-Withdrawl_Amount
      Balance=customer["Amount"]
  else:
    print("Invalid PIN")
def Deposit():
  pin=int(input("Enter your pin"))
  if pin==customer["pin"]:
    print("Enter the amount")
    Deposit_Amount=int(input())
    customer["Amount"]=customer["Amount"]+Deposit_Amount
  else :
    print("Invalid PIN")
def PIN_Change ():
  pin=int(input("Enter your pin"))
  if pin==customer["pin"]:
    new_pin=input("Enter your new pin")
    customer["pin"]=new_pin
  else :
    print("Invalid PIN")
def check_balance ():
   pin=int(input("Enter your pin"))
   if pin==customer["pin"]:
    print(customer["Amount"])
   else :
    print("Invalid PIN")
def Exit():
   print("Thank You")
def Home_Page():
  while True:
   print("Choose Services")
   print("Enter 1 for Withdrwal")
   print("Enter 2 for Deposit")
   print("Enter 3 for PIN change")
   print("Enter 4 for Check Balance")
   print("Enter 5 for Exit" )
   choice=int(input())
   if choice==1:
     Withdrwal()
   elif(choice==2):
     Deposit()
   elif(choice==3):
      PIN_Change()
   elif(choice==4):
     check_balance()
   elif(choice==5):
     Exit()
print("Go to home page")
print("Enter 1 for Home Page")
print("Enter 2 for Exit")
option=int(input())
if option==1:
  Home_Page()
else :
  Exit()
# Out:
# Go to home page
# Enter 1 for Home Page
# Enter 2 for Exit
# 1
# Choose Services
# Enter 1 for Withdrwal
# Enter 2 for Deposit
# Enter 3 for PIN change
# Enter 4 for Check Balance
# Enter 5 for Exit
# 1
# Enter your pin5000
# Invalid PIN
# Choose Services
# Enter 1 for Withdrwal
# Enter 2 for Deposit
# Enter 3 for PIN change
# Enter 4 for Check Balance
# Enter 5 for Exit
# 1
# Enter your pin3007
# Enter the amount
# 5000
# Insufficient Balance
# Choose Services
# Enter 1 for Withdrwal
# Enter 2 for Deposit
# Enter 3 for PIN change
# Enter 4 for Check Balance
# Enter 5 for Exit
# 2
# Enter your pin3007
# Enter the amount
# 2000
# Choose Services
# Enter 1 for Withdrwal
# Enter 2 for Deposit
# Enter 3 for PIN change
# Enter 4 for Check Balance
# Enter 5 for Exit
# 4
# Enter your pin3007
# 3000
# Choose Services
# Enter 1 for Withdrwal
# Enter 2 for Deposit
# Enter 3 for PIN change
# Enter 4 for Check Balance
# Enter 5 for Exit
